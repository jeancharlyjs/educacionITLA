# %% [markdown]
# # Que es una función?
#
# # $f(x) = y $
#
# ### Propiedades
#     - Parametros
#     - Proceso
#     - Salida
#
# x = [3, 4, 4 , 5]
#
# $f(x) = 2x + 4\\$
# $f(3) = 2(3) + 4\\$

# %% [markdown]
# # Tipos de Funciones
#
# *   Creadas
# *   Definidas
# *   Anonimas
# *   Matematicas
# *   Recursivas
# *   Del Sistema
#
# ```
# FUNCION <NOMBRE_FUNCION>(P_1, P_2, P_N){
#     PROCESO
#     PROCESO...
#     PROCESO...
# }
# RETORNO PROCESO_FINAL
# ```
#
# <NOMBRE_FUNCION(ARGUMENTO_1, ARGURMENTO_2)>

# %%
# Funcion Creada

def promedio(n1, n2, n3, n4) -> float:
    # Promedio = sum(valores)/ cantidad(valor)
    promedio = sum([n1, n2, n3, n4]) / 4
    # print("Promedio: ", promedio)
    return promedio

elemento1 = promedio()

# %%
print("Promedio: ", elemento1)
# Out:
# Promedio:  15.5

# %%
# Funcion Definidas
import numpy as np

np.average([3, 4, 50, 5])

print("Hola")
len([3, 4, 50, 5])
len("Hola a todos")
# Out:
# Hola
# 12

# %%
saludo = 'Hola a todos'
contar = 0

for i in range(len(saludo)):
    contar += len(saludo[i])

print(contar)
# Out:
# 12

# %%
elemento = lambda x: x * 2

# %%
elemento(5)

def elemento2(x):
    return x * 2
elemento2(5)
# Out:
# 10

# %%
import math
import statistics
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $x = h + r * \cos *\theta\\$
# $y = k + r * \sin * \theta$

# %%
x = np.linspace(1, 5, 100000)
y = np.linspace(1, 5, 100000)


#Grafico
plt.title("Grafico de Funcioines Trigonometricas\n Estudiantes ITLA")
plt.plot(np.sin(x), label='Seno')
plt.plot(np.cos(y), label="Coseno")
plt.xlabel('sin')
plt.ylabel('cos')
plt.legend()
plt.show()

# %%
def circunferencia(h, k, r, t):
    contar = 0
    for i in range(5):
        c = np.linspace(0, 2 * np.pi, t)
        x = h + r * np.cos(c)
        y = k + r * np.sin(c)
        contar += 1
        plt.plot(x / y * contar, y / y * x)
        
    return plt.show()

circunferencia(10, 10, 5, 100000)

# %%
# Funcion Recursivas


def prueba():
    return prueba()

prueba()

# %%
# Conjetura de Collatz

### Si N es par entonces Modulo 2
### Si N es impar entonces 3n + 1

def conjeturaCollatz(n, sec: list):
    sec.append(n)
    if n == 1:
        return 
    elif n % 2 == 0:
        return conjeturaCollatz(n / 2, sec)
    else:
        return conjeturaCollatz(3 * n + 1, sec)

# %%
secuencia = []
conjeturaCollatz(2234234, secuencia)
plt.plot(secuencia, '-*')
plt.show()
