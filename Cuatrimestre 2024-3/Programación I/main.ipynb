# %% [markdown]
# ## Formula
#
# # $f'(x) = \frac{f(x_{i+1}) - f(x_i)}{h}$

# %%
x = [1, 3, 4, 5, 6]
#Python
def derivada(x1, x2, h):
    return (x1 - x2) / h

# %%
#JavaScript
function derivada(x1, x2, h){

} return (x1 - x2) / h

# %%
for i in range(len(x) -1):
    print(derivada(x[i+1], x[i], 2))
# Out:
# 1.0
# 0.5
# 0.5
# 0.5

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.array(x)
s = np.sin(np.linspace(1, 5, 10000))
c = np.cos(np.linspace(1, 5, 10000))

plt.title("Funciones Trigonometricas")
plt.plot(s, label="seno")
plt.plot(c, label='coseno')
plt.legend()
plt.xlabel("x")
plt.ylabel('y')
plt.show()

# %%
plt.plot(s)

# %% [markdown]
# # Logica y Demostraciones

# %% [markdown]
# p: Esta lloviendo\
# q: Hace frio
#
# * Proposicion Simple\
#     Son aquellas que no tienen conectores logicos
#
# * Prosicion Compuesta\
#     Son aquellas que contienen conectores logicos, y son lo siguientes\
#
#     ### Operadores Logicos
#     ```
#     - AND -> Y -> &&  V = VV
#     - OR  -> O -> ||  V = VF
#     - Not -> No ->    V = F; F = V
#     ```
#
#     ### Operadores Comparacion
#
#     ```
#     ==  Igual que; ===
#     <   Menor que
#     >   Mayor que
#     <=  Menor igual que
#     >=  Mayor igual que
#     <>; ~; !=   Diferencia
#     ```

# %% [markdown]
# #Fase 1 -> AND -. Conjunción
#
# $\begin{matrix}
# p &  q & p \land q\\
# V & V & V\\
# V & F & F\\
# F & V & F\\
# F & F & F\\
# \end{matrix}$
#
# p   ^   q #Esta lloviendo y hace frio
# V       V
#     V

# %% [markdown]
# ### AND - && - and

# %%
a = 5 > 10
b = 0 == 10

(5 > 10) and (0 == 10)
#   F            F
#         F
# Out:
# False

# %% [markdown]
# #Fase 2 -> OR -. Disyuntiva
#
# $\begin{matrix}
# p &  q & p \lor q\\
# V & V & V\\
# V & F & V\\
# F & V & V\\
# F & F & F\\
# \end{matrix}$
#
# p   v   ~q #Esta lloviendo y no hace frio
# V       F
#     V

# %% [markdown]
# # OR - || - or

# %%
(5 > 10) or not(0 == 10)
# F            V
#         V
# Out:
# True

# %% [markdown]
# ## La Condicional ->
# $ p \rightarrow q$
#
# $\begin{matrix}
# p &  q & p \rightarrow q\\
# V & V & V\\
# V & F & F\\
# F & V & V\\
# F & F & V\\
# \end{matrix}$
#
#
# ```
# SI (PROPOSICION) ENTONCES
#     SENTENCIA [VERDADERO]
# SINO
#     SENTENCIA
# ```
#
# ```
# SI (PROPOSICION) {
#     SENTENCIA [VERDADERO]
# }SINO{
#     SENTENCIA
# }
#
# ```

# %%
if (5 > 10) or not(0 == 10):
    print("El resultado esta excelente")
else:
    print("Algo esta mal")
# Out:
# El resultado esta excelente

# %% [markdown]
# "El ITLA propone darle becas a estudiantes si su indice es mayor o igual 80 y que sea mayor igual a 16 años de edad"

# %% [markdown]
# ## $$\sum^{n}_{i=1} x_i; y_i$$

# %%
from random import randint
# indice = [ randint(60, 90) for i in range(11)]
# edad = [ randint(13, 25) for i in range(11)]
for i in range(len(indice)):
    if edad[i] >= 16 and indice[i] >= 80:
        print(f"{indice[i]} {edad[i]} -> Becado")
    else:
        print(f"{indice[i]} {edad[i]} -> No becado")
# Out:
# 63 20 -> No becado
# 82 16 -> Becado
# 81 20 -> Becado
# 73 25 -> No becado
# 84 14 -> No becado
# 73 24 -> No becado
# 90 16 -> Becado
# 87 23 -> Becado
# 65 14 -> No becado
# 65 22 -> No becado
# 62 16 -> No becado

# %% [markdown]
# # Cuantificadores
#
# * Existencia $\exists$ -> in
# * Universo $\forall$ - is

# %%
elementos = [2, 3, 4, 5, 6, 7]
print(10 in elementos)
# Out:
# False

# %% [markdown]
# ### Listas
#
# _Mutables_
#
# - Propiedad de la listas
#     - Vectores
#         - Vectores Columnas
#         - Vectores Filas
#     - Matrices
#
# - Tamaño
#     * len(elemento)
# - Indice
#     elemento[indice]
#
# - Slices
#     * elemento[:a]
#     * elemento[a:]
#     * elemento[a:b]
#     * elemento[:]
# - Metodos
#     - append
#     - extender
#     - pop

# %%
elementos = [2, 3, 4, 5, 6, 7]
print(elementos)
print("Tamaño: ", len(elementos))

print(elementos[-1])

#[:a]
print(elementos[:3])

#[a:]
print(elementos[4:])

#[a:b]
print(elementos[2:6])

print(elementos[:])

#lista
elemento1 = ["Jean CHarly", 342, True, None]

#Arreglo
nombre = ["Jean Charly", "Nikola", "Marie Curie"]

#Vector
vector1 = [[1.5, 3.0, 4.0, 5.0, 6.0, 7.0]]

matrices1 = [[[1, 3, 4, 5]], [[3, 4, 5, None]]]
# Out:
# [2, 3, 4, 5, 6, 7]
# Tamaño:  6
# 7
# [2, 3, 4]
# [6, 7]
# [4, 5, 6, 7]
# [2, 3, 4, 5, 6, 7]

# %% [markdown]
# ### Matrices

# %%
import numpy as np

matrices = np.array([[1, 3, 4, 5], [3, 4, 5, 6], [3, 4, "Jean", 6]])
matrices[2][2] = 0
matrices = np.array(matrices, dtype=np.int8)
matrices

matrices[:, 1]
# Out:
# array([3, 4, 4], dtype=int8)

# %%
scalar = 5
elemento2 = [1, 3, 4, 5]

#Arreglo
print([elemento2[i] * scalar for i in range(len(elemento2))])

vector = np.array([1, 3, 4, 5])
print(vector * scalar)
# Out:
# [5, 15, 20, 25]
# [ 5 15 20 25]

# %%
par   = []
impar = []
for i in range(len(elementos)):
    if elementos[i] % 2 == 0:
        print(elementos[i], "es par")
        par.append(elementos[i])
    else:
        print(elementos[i], 'es impar')
        impar.append(elementos[i])
# Out:
# 2 es par
# 3 es impar
# 4 es par
# 5 es impar
# 6 es par
# 7 es impar

# %%
print("Par:\t", par)
print("Impar:\t", impar)
# Out:
# Par:	 [2, 4, 6]
# Impar:	 [3, 5, 7]

# %%
edad = 18
sexo = True
A -> B

#Bloque A
SI EDAD >= 18 ENTONCES
    #Bloque B
    SI SEXO == TRUE ENTONCES
        IMPRIMIR("ERES UNA FEMENINA MAYOR DE EDAD")

# %% [markdown]
# # Conjuntos
#
# $$A = \{1, 2, 3, 4\}$$
# $$B = \{x | x\ es\ un\ entero\ par,\ positivo\}$$

# %% [markdown]
# $X = \{2, 3, 4, 5, 6\}\\$
# $Y =\{2, 3, 4, 5, 8, 10\}$
#
# - Unificar
#
# $X \cup Y = \{x | x \in X\ \lor x \in Y$\}

# %%
#Unificar ( | )
X = {2, 3, 4, 5, 6}
Y = {2, 3, 4, 5, 8, 10}

print(X | Y)
# Out:
# {2, 3, 4, 5, 6, 8, 10}

# %% [markdown]
# $X = \{2, 3, 4, 5, 6\}\\$
# $Y =\{2, 3, 4, 5, 8, 10\}$
#
# - Intersecccion
#
# $X \cap Y = \{x | x \in X\ \land x \in Y$\}

# %%
#Interseccion ( & )
X = {2, 3, 4, 5, 6}
Y = {2, 3, 4, 5, 8, 10}

print(X & Y)
# Out:
# {2, 3, 4, 5}

# %% [markdown]
# $X = \{2, 3, 4, 5, 6\}\\$
# $Y =\{2, 3, 4, 5, 8, 10\}$
#
# - Diferencia
#
# $X - Y = \{x | x \in X\ \land x \notin Y$\}\
# $Y - X = \{x | x \in Y\ \land x \notin X$\}

# %%
#Diferencia ( - )
# X - Y
X = {2, 3, 4, 5, 6}
Y = {2, 3, 4, 5, 8, 10}

print(X - Y)
print(Y - X)
# Out:
# {6}
# {8, 10}

# %%
#Add
X.add(234)
Y.add(34)
print(X)
print(Y)
# Out:
# {2, 3, 4, 5, 6, 234}
# {2, 3, 4, 5, 34, 8, 10}

# %%
#Remove
X.remove(234)
print(X)
# Out:
# {2, 3, 4, 5, 6}

# %%
from shapely.geometry import Point, Polygon

# %%
p1 = Point([2, 4])

# %%
p2 = Polygon([[2, 4], [3, 5], [2, 4]])

# %%
p2.intersection(p1)
# Out:
# <POINT (2 4)>

# %%
db1 = {'nombre', 'apellidos', 'edad'} #Banco de Resevas
db2 = {'nombres', 'telef', 'email'} #Popular
db3 = {'apellidos', 'telef'} #BHD

GENERAL = {}

# %%
db2 - db1
# Out:
# {'email', 'nombres', 'telef'}

# %%
db1 | (db2 - db3) #or db1 - db3
# Out:
# {'apellidos', 'edad', 'email', 'nombre'}

# %%
db3 - db1
# Out:
# {'telef'}

# %%
db1 - db3 | db2
# Out:
# {'edad', 'email', 'nombre', 'telef'}

# %%
list(db1)
# Out:
# ['apellidos', 'nombre', 'edad']

# %% [markdown]
# {
#
#     Codigo
# }
# #Documentacion

# %% [markdown]
# ## Funciones

# %% [markdown]
# $d = v * t$\
# $f(x) = y$
#
# * Tipos variables
#     - Variables dependientes $y$
#     - Variables independiente $x$
#
# ```
# FUNCION <NOMBRE>(P1, P2, P3, PN) {
#     SENTENCIA
#     IMPRIMIR
# }RETORNAR
# ```
#
# - Tipos de Funciones
#     - Funcion Definida
#     - Funcion Definida por el Lenguaje
#     - Funcion Anonimas
#     - Funcion Recursivas $f(f(x))$
#     - Funcion Matematicas (sqrt, pi, e)
#     - Funcion Modular
#     - Funcion Trigonometricas (sin, cos, tan)
#     - Funcion Sistema Operativo

# %%
#Funcion Definda

def operacion(p1, p2, p3, pn):
    try:
        resultado = ((p1 + p2 + p3 ) / pn)
        print(resultado)
        return resultado
    except ZeroDivisionError:
        print("Amigo, no se puede dividir entre cero... :(")
x = operacion(23, 34, 12, 23)
x * 100
# Out:
# 3.0
# 300.0

# %% [markdown]
# $5x^2+3x+10$

# %%
from random import randint

x = [randint(1, 100) for i in range(30)]
y = []
def ecuacionSegundoOrden(x):
    valor = 5 * x**2 + 3 * x + 10
    return valor

for i in range(len(x)):
    y.append(ecuacionSegundoOrden(x[i]))

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y);plt.show()

# %% [markdown]
# # Funcion Anonima
#
# ## $\lambda x: x [* + - / //] \mathbb{R^{+}}$

# %%
#Funcion Anonimas

elemento = lambda x: 5 * x**2 + 3 * x + 10
elemento(4)
# for i in range(len(x)):
#     print(elemento(x[i]))
# Out:
# 102

# %% [markdown]
# $f(x) = n(n-1)$

# %%
# Funcion Recursivas
def recursivas(x):
    if x == 0:
        return "Felicidades, haz cumplido la meta"
    else:
        print("Valor de x: ", x)
        return recursivas(x -1)
    
recursivas(10)
# Out:
# Valor de x:  10
# Valor de x:  9
# Valor de x:  8
# Valor de x:  7
# Valor de x:  6
# Valor de x:  5
# Valor de x:  4
# Valor de x:  3
# Valor de x:  2
# Valor de x:  1
# 'Felicidades, haz cumplido la meta'

# %%
import math


math.pi
math.e

resultadoSIN = [math.sin(x[i]) for i in range(len(x))]
plt.plot(resultadoSIN)

# %%
[[round(math.sin(x[i]),8)] for i in range(len(x))]
# Out:
# [[0.31322878],
#  [0.14987721],
#  [-0.82181784],
#  [0.52908269],
#  [0.85090352],
#  [0.43616476],
#  [-0.66363388],
#  [-0.11478481],
#  [0.14987721],
#  [-0.96611777],
#  [0.98358775],
#  [0.99991186],
#  [0.99952016],
#  [0.91294525],
#  [-0.53657292],
#  [-0.15862267],
#  [-0.96611777],
#  [-0.83177474],
#  [-0.00885131],
#  [0.86006941],
#  [0.90929743],
#  [0.90929743],
#  [-0.2794155],
#  [-0.28790332],
#  [0.01770193],
#  [0.86006941],
#  [-0.15862267],
#  [0.86006941],
#  [-0.99388865],
#  [0.91294525]]

# %%
import numpy as np


x_ = np.array(x)
np.sin(x_).reshape(-1, 1)
# Out:
# array([[ 0.31322878],
#        [ 0.14987721],
#        [-0.82181784],
#        [ 0.52908269],
#        [ 0.85090352],
#        [ 0.43616476],
#        [-0.66363388],
#        [-0.11478481],
#        [ 0.14987721],
#        [-0.96611777],
#        [ 0.98358775],
#        [ 0.99991186],
#        [ 0.99952016],
#        [ 0.91294525],
#        [-0.53657292],
#        [-0.15862267],
#        [-0.96611777],
#        [-0.83177474],
#        [-0.00885131],
#        [ 0.86006941],
#        [ 0.90929743],
#        [ 0.90929743],
#        [-0.2794155 ],
#        [-0.28790332],
#        [ 0.01770193],
#        [ 0.86006941],
#        [-0.15862267],
#        [ 0.86006941],
#        [-0.99388865],
#        [ 0.91294525]])

# %%
plt.plot(np.sin(np.linspace(-5, 5, 1000)) * np.pi)

# %%
5 * np.array(x)**2 + 3 * np.array(x) + 10
# Out:
# array([33876,  1872, 38116,  5892, 10270, 16426,  4302, 24022,  1872,
#        18798, 46378,  5554, 29886,  2070,   766,  8538, 18798,  9384,
#         2496, 39882,    36,    36,   208,  1338,  9822, 39882,  8538,
#        39882, 32250,  2070])

# %% [markdown]
# # Introducción a la Programación Orientada Objetos
#
# ### Pilas
#     - Herencia
#     - Polimorfismo
#     - Abstracción
#
#
# #### Estructuras Dinamicas
#
#     - Filas
#     - Colas
#     - Listas
#         - Lista Enlazadas
#         - Lista Doblemente Enlazadas
#         - Lista Circular
#     - Arboles

# %%
class Nodos:
    def __init__(self, nodos):
        self.nodos = nodos
        self.lista = []
    def __repr__(self):
        return f"Bienvenido: {self.nodos}"
    def AgregarNodo(self, n):
        return self.lista.append([n])
    def VisualizacionNodos(self):
        return self.lista
    def Ruta(self):
        nodos = VisualizacionNodos()

# %%
n1 = Nodos("A")
print(n1)
# Out:
# Bienvenido: A

# %%
n2 = Nodos("B")
print(n2)
# Out:
# Bienvenido: B

# %%
n3 = Nodos("C")
print(n3)
# Out:
# Bienvenido: C

# %%
n1.AgregarNodo(n2.nodos)
n1.VisualizacionNodos()
# Out:
# [['B']]

# %%
n2.AgregarNodo(n3.nodos)
n2.VisualizacionNodos()
# Out:
# [['C']]

# %%
n2.AgregarNodo("D")
n2.VisualizacionNodos()
# Out:
# [['C'], ['D']]

# %% [markdown]
# #### Filas

# %%
class Filas:
    contar = 0
    def __init__(self, nombre):
        self.nombre = nombre
        # self.edad = edad
        self.listado = []
        self.prioridad = []
        # self. estatdo = None
    def AgregarElemento(self, n):
        if n >= 60:
            self.prioridad.append(n)
            return self.prioridad
        else:
            self.listado.append(n)
            return self.listado
    def Visualizacion(self):
        print(f"Prioridad: {self.prioridad}\nListado: {self.listado}")

    def Atender(self):
        if len(self.listado) == 0:
            print("No hay listado....")
        else:
            self.listado.pop(0) 
            self.contar += 1
        if self.contar == 2:
            if len(self.prioridad) == 0:
                print("No hay prioridad....")
            self.prioridad.pop(0)
            self.contar = 0

# %%
from random import randint

# for i in range(21):
# f = Filas(f"nombre_{randint(18, 80)}")
f.AgregarElemento(randint(18, 80))
print(f.Visualizacion())
# Out:
# Prioridad: [67, 72, 72, 74, 63, 74, 74, 79]
# Listado: [20, 51, 19, 52, 30, 41, 22, 35, 47, 39, 55, 50, 22]
# None

# %%
f.Atender()
print(f.Visualizacion())
# Out:
# No hay listado....
# Prioridad: [74, 79]
# Listado: []
# None

# %%
contar = 0

# %%
contar += 1
contar
# Out:
# 7
