# %% [markdown]
# # Variables
# * Primitiva
# * Colectora
# * Sistema Operativo

# %% [markdown]
# ### Primitivas
# * String
# * Integer
# * Boolean
# * Float
# * Complex

# %% [markdown]
# ## String

# %%
nombre = "Jean Charly"

# %%
print(type(nombre))
# Out:
# <class 'str'>

# %%
nombre1 = "jean cHarLy"
print(nombre1)
# Out:
# jean cHarLy

# %%
nombre1.title()
# Out:
# 'Jean Charly'

# %%
nombre1.capitalize()
# Out:
# 'Jean charly'

# %%
nombre1 = nombre1.title()
nombre1
# Out:
# 'Jean Charly'

# %% [markdown]
# ## Integer

# %%
numero = 20

# %%
dir(numero)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'numerator',
#  'real',
#  'to_bytes']

# %%
numero = '20'
numero = int(numero)
type(numero)
# Out:
# int

# %% [markdown]
# ## String - Numeros

# %%
nombre = "Jean Charly "
edad = 32

# %%
nombre + 3.14
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /workspaces/educacionITLA/Introd. Programacion I.ipynb Celda 16 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bhumble-space-carnival-5gwvg7qrr4qhv79/workspaces/educacionITLA/Introd.%20Programacion%20I.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> nombre + 3.14
#
# TypeError: can only concatenate str (not "float") to str

# %%
nombre * 2
# Out:
# 'Jean Charly Jean Charly '

# %%
nombre = "Jean Charly Ph."
apellido = "Joseph S."

# %%
nombreCompleto = nombre + apellido
nombreCompleto
# Out:
# 'Jean Charly Ph.Joseph S.'

# %%
edad = int(input("Ingrese su edad: "))
type(edad)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /workspaces/educacionITLA/Introd. Programacion I.ipynb Celda 20 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bhumble-space-carnival-5gwvg7qrr4qhv79/workspaces/educacionITLA/Introd.%20Programacion%20I.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> edad = int(input("Ingrese su edad: "))
#       <a href='vscode-notebook-cell://codespaces%2Bhumble-space-carnival-5gwvg7qrr4qhv79/workspaces/educacionITLA/Introd.%20Programacion%20I.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> type(edad)
#
# ValueError: invalid literal for int() with base 10: '"Hola"'

# %% [markdown]
# #No Tipado
#
# <tipo> <variable> = <valor>
#
#
# #Tipado
# <variable> = <valor>

# %% [markdown]
# # Colectoras

# %% [markdown]
# #### Lista

# %%
# Listas - > [ ]

- append
- extend
- clear
- pop
- remove

# %%
elemento = ["Jean Charly", 32, 1.8, 4j, ["Ciencia", "Documentales", "Lectura"]]

# %%
id(elemento)
# Out:
# 140491668276736

# %%
elemento1 = elemento

# %%
elemento1.append(["Nikola Tesla", "Marie Curie"])

# %%
elemento1
# Out:
# ['Jean Charly',
#  32,
#  1.8,
#  4j,
#  ['Ciencia', 'Documentales', 'Lectura'],
#  ['Nikola Tesla', 'Marie Curie']]

# %%
elemento
# Out:
# ['Jean Charly',
#  32,
#  1.8,
#  4j,
#  ['Ciencia', 'Documentales', 'Lectura'],
#  ['Nikola Tesla', 'Marie Curie']]

# %%
id(elemento)
# Out:
# 140491668276736

# %%
id(elemento1)
# Out:
# 140491668276736

# %% [markdown]
# ## $$\sum^{N}_{i=1} x_i$$
#
# * N = Cantidad de elementos
# * i = Indice del elemento

# %%
len(elemento)
# Out:
# 6

# %%
elemento[0]
# Out:
# 'Jean Charly'

# %%
for i in range(7):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(len(elemento)):
    print(i, "<<<>>>", elemento[i])
# Out:
# 0 <<<>>> Jean Charly
# 1 <<<>>> 32
# 2 <<<>>> 1.8
# 3 <<<>>> 4j
# 4 <<<>>> ['Ciencia', 'Documentales', 'Lectura']
# 5 <<<>>> ['Nikola Tesla', 'Marie Curie']

# %%
elemento.append(())
for i in range(len(elemento)):
    print(i, "<<<>>>", elemento[i], "<<<<>>>", type(elemento[i]))
# Out:
# 0 <<<>>> Jean Charly <<<<>>> <class 'str'>
# 1 <<<>>> 32 <<<<>>> <class 'int'>
# 2 <<<>>> 1.8 <<<<>>> <class 'float'>
# 3 <<<>>> 4j <<<<>>> <class 'complex'>
# 4 <<<>>> ['Ciencia', 'Documentales', 'Lectura'] <<<<>>> <class 'list'>
# 5 <<<>>> ['Nikola Tesla', 'Marie Curie'] <<<<>>> <class 'list'>
# 6 <<<>>> () <<<<>>> <class 'tuple'>
# 7 <<<>>> () <<<<>>> <class 'tuple'>

# %%
elemento + ["Gauss"]
# Out:
# ['Jean Charly',
#  32,
#  1.8,
#  4j,
#  ['Ciencia', 'Documentales', 'Lectura'],
#  ['Nikola Tesla', 'Marie Curie'],
#  (),
#  (),
#  'Gauss']

# %% [markdown]
# #### Arreglo / Vectores
#
# * Vector Filas
# * Vector Columna

# %%
v = [2, 4, 5, 6, 7] #Numerico
v
# Out:
# [2, 4, 5, 6, 7]

# %%
v * 5
# Out:
# [2, 4, 5, 6, 7, 2, 4, 5, 6, 7, 2, 4, 5, 6, 7, 2, 4, 5, 6, 7, 2, 4, 5, 6, 7]

# %%
v + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /workspaces/educacionITLA/Introd. Programacion I.ipynb Celda 42 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bhumble-space-carnival-5gwvg7qrr4qhv79/workspaces/educacionITLA/Introd.%20Programacion%20I.ipynb#X65sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> v + 1
#
# TypeError: can only concatenate list (not "int") to list

# %%
v + [3, 4, 5]
# Out:
# [2, 4, 5, 6, 7, 3, 4, 5]

# %%
v - [3, 4, 5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /workspaces/educacionITLA/Introd. Programacion I.ipynb Celda 44 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bhumble-space-carnival-5gwvg7qrr4qhv79/workspaces/educacionITLA/Introd.%20Programacion%20I.ipynb#X66sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> v - [3, 4, 5]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
v / [3, 4, 5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /workspaces/educacionITLA/Introd. Programacion I.ipynb Celda 46 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bhumble-space-carnival-5gwvg7qrr4qhv79/workspaces/educacionITLA/Introd.%20Programacion%20I.ipynb#Y100sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> v / [3, 4, 5]
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
#numpy 

import numpy as np

# %%
v_1 = np.array([2, 3, 4, 5])

# %%
v_1 * 5
# Out:
# array([10, 15, 20, 25])

# %%
v_1.reshape(-1, 1) * v_1
# Out:
# array([[ 4,  6,  8, 10],
#        [ 6,  9, 12, 15],
#        [ 8, 12, 16, 20],
#        [10, 15, 20, 25]])

# %% [markdown]
# ### Tupla

# %%
registro = (234234, "Jean Charly", "Josh", False, ["Hola"])

# %%
registro[2] = "Joseph"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 registro[2] = "Joseph"
#
# TypeError: 'tuple' object does not support item assignment

# %%
registro[-1].append("Nikola Tesla")

# %%
registro
# Out:
# (234234, 'Jean Charly', 'Josh', False, ['Hola', 'Nikola Tesla'])

# %%
registro[-1].append("Nueva contraseña")

# %%
registro[0:4]
# Out:
# (234234, 'Jean Charly', 'Josh', False)

# %%
dir(registro)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dir(registro)
#
# NameError: name 'registro' is not defined

# %% [markdown]
# # Diccionario
#
# ### { llave : valor }
#
# ### Componentes:
# - Estructurados
# - Semi estructurado
# - No estructurado

# %%
import polars as pl

# %%
registroEstudiantil = {
    "Jean Charly": [23423, "Jean Charly", "Joseph", 32, False, 29384729834,],
    "Nikola Tesla": [23423, "Jean Charly", "Joseph", None, False, 29384729834,]
}

# %%
registroEstudiantil["Jean Charly"]
# Out:
# [23423, 'Jean Charly', 'Joseph', 32, False, 29384729834]

# %%
registroEstudiantil["Marie Curie"] = []

# %%
registroEstudiantil
# Out:
# {'Jean Charly': [23423, 'Jean Charly', 'Joseph', 32, False, 29384729834],
#  'Nikola Tesla': [23423, 'Jean Charly', 'Joseph', None, False, 29384729834],
#  'Marie Curie': []}

# %%
registroEstudiantil["Marie Curie"] = [None, None, None, None, None, None]

# %%
pl.DataFrame(registroEstudiantil)
# Out:
# shape: (6, 3)
# ┌─────────────┬──────────────┬─────────────┐
# │ Jean Charly ┆ Nikola Tesla ┆ Marie Curie │
# │ ---         ┆ ---          ┆ ---         │
# │ str         ┆ str          ┆ f32         │
# ╞═════════════╪══════════════╪═════════════╡
# │ null        ┆ null         ┆ null        │
# │ Jean Charly ┆ Jean Charly  ┆ null        │
# │ Joseph      ┆ Joseph       ┆ null        │
# │ null        ┆ null         ┆ null        │
# │ null        ┆ null         ┆ null        │
# │ null        ┆ null         ┆ null        │
# └─────────────┴──────────────┴─────────────┘

# %%
ITLA = {
    "Matematicas": {
        "Estudiantes":{
            "Estua1": [],
            "Estua2": []
        }
    },
    "Fisica": {
        "Estudiantes": {
            "Estua1":[],
            "Estua2":[],
            "Estua3":[]
        }
    }
}

# %%
elementoDicc = {"Nombre": ["Jean Charly", "Nikola"], "Apellido": ["Joseph", "Tesla"], "Edad": [32, 20], "Sexo": [False, False]}
elementoDicc
# Out:
# {'Nombre': ['Jean Charly', 'Nikola'],
#  'Apellido': ['Joseph', 'Tesla'],
#  'Edad': [32, 20],
#  'Sexo': [False, False]}

# %%
elementoDicc['Nombre']
# Out:
# ['Jean Charly', 'Nikola']

# %%
elemento1 = [
    {
        "elemento": [1, 2, 3, 4]
    },
    {
        "elemento2": [2, 4, 5, 4]
    }
]

# %%
elemento1[0]['elemento'][2] = "Jean Charly"
elemento1
# Out:
# [{'elemento': [1, 2, 'Jean Charly', 4]}, {'elemento2': [2, 4, 5, 4]}]

# %% [markdown]
# # $$f(x) = \alpha * \beta$$
