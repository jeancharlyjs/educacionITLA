# %% [markdown]
# !pwd

# %%
# !pwd
# Out:
# /workspaces/educacionITLA/2025/Cuatrimestre 2025-01/Programación II/Miercoles

# %%
import numpy as np
import matplotlib.pyplot as plt

def ecuacionExponencial(x):
    return 2 ** x + 5
x = np.linspace(-10, 0, 10)
y = ecuacionExponencial(x)

plt.plot(x, y)
plt.show()
