# %%
edad = int(input("Ingrese su edad: "))
5 > 3 and 19 < edad
# Out:
# False

# %%
edad < 19
# Out:
# False

# %%
20 < 19
# Out:
# False

# %%
19 < 20
# Out:
# True

# %% [markdown]
# ### Condiciones Anidada
#
# ```
# SI CONDICION (){
#     RESULTADO
#     SI CONDICION () {
#         RESULTADO
#     } DE LO CONTRARIO {
#         RESULTADO
#     }
# }DE LO CONTRARIO{
#     RESULTADO
# }
# ```

# %%
edad = 20
sexo = 2

if edad > 19: #Primera Condicion
    print("Excelente")
    if sexo == 1: #Segunda Condicion
        print("Excelente, ella es muy inteligente")
    else:
        print("Algo paso")
else:
    print("Usted es menor que 19")
# Out:
# Excelente
# Algo paso

# %%
if edad > 19 and sexo ==1:
    print("Excelnte. Ella es muy inteligente")
else:
    print("Algo paso")
# Out:
# Algo paso

# %%
edad = int(input("Ingrese su edad: "))
if edad >= 18:
    print("Es mayor de edad.")
elif edad >= 14 and edad <= 18:
    print("Adolencente")
else:
    print("es un menor")
# Out:
# Adolencente

# %%
edad = int(input("Ingrese su edad: "))

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def rosenbrock(x, y):
    """Función de Rosenbrock"""
    return (1 - x)**2 + 100 * (y - x**2)**2

def derivada_x(x, y):
    """Derivada parcial de la función de Rosenbrock respecto a x"""
    return -2 * (1 - x) - 400 * x * (y - x**2)

def derivada_y(x, y):
    """Derivada parcial de la función de Rosenbrock respecto a y"""
    return 200 * (y - x**2)

def gradiente_descendente(x, y, alpha=0.001, iteraciones=1000):
    """Algoritmo de descenso de gradiente"""
    historial_costo = []
    historial_x = []
    historial_y = []
    
    for i in range(iteraciones):
        # Calcular las derivadas parciales
        derivada_x_actual = derivada_x(x, y)
        derivada_y_actual = derivada_y(x, y)
        
        # Actualizar x y y usando el descenso de gradiente
        x -= alpha * derivada_x_actual
        y -= alpha * derivada_y_actual
        
        # Registrar el costo y las coordenadas actuales
        historial_costo.append(rosenbrock(x, y))
        historial_x.append(x)
        historial_y.append(y)
        
    return x, y, historial_costo, historial_x, historial_y

# Punto de inicio para el descenso de gradiente
x, y = -2, 2


# Realizar el descenso de gradiente
x_optimo, y_optimo, historial_costo, historial_x, historial_y = gradiente_descendente(x, y, alpha=0.001, iteraciones=1000)

# Crear una figura 3D
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# Crear una malla de puntos para la superficie de la función de Rosenbrock
x_vals = np.linspace(-3, 3, 100)
y_vals = np.linspace(-3, 3, 100)
x_mesh, y_mesh = np.meshgrid(x_vals, y_vals)
z_mesh = rosenbrock(x_mesh, y_mesh)

# Graficar la superficie de la función de Rosenbrock
ax.plot_surface(x_mesh, y_mesh, z_mesh, cmap='viridis', alpha=0.8)


# Graficar el historial de puntos encontrados por el descenso de gradiente
ax.plot(historial_x, historial_y, historial_costo, color='green', marker='o')


# Configuración de la etiqueta de los ejes
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Costo')

# Mostrar la gráfica
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def rosenbrock(x, y):
    """Función de Rosenbrock"""
    return (1 - x)**2 + 100 * (y - x**2)**2

def derivada_x(x, y):
    """Derivada parcial de la función de Rosenbrock respecto a x"""
    return -2 * (1 - x) - 400 * x * (y - x**2)

def derivada_y(x, y):
    """Derivada parcial de la función de Rosenbrock respecto a y"""
    return 200 * (y - x**2)

def gradiente_descendente(x, y, alpha=0.001, iteraciones=1000):
    """Algoritmo de descenso de gradiente"""
    historial_costo = []
    historial_x = []
    historial_y = []
    
    for i in range(iteraciones):
        # Calcular las derivadas parciales
        derivada_x_actual = derivada_x(x, y)
        derivada_y_actual = derivada_y(x, y)
        
        # Actualizar x y y usando el descenso de gradiente
        x -= alpha * derivada_x_actual
        y -= alpha * derivada_y_actual
        
        # Registrar el costo y las coordenadas actuales
        historial_costo.append(rosenbrock(x, y))
        historial_x.append(x)
        historial_y.append(y)
        
    return x, y, historial_costo, historial_x, historial_y

# Punto de inicio para el descenso de gradiente
x, y = -2, 2

# Realizar el descenso de gradiente
x_optimo, y_optimo, historial_costo, historial_x, historial_y = gradiente_descendente(x, y, alpha=0.001, iteraciones=1000)

# Crear una figura 3D para la superficie de Rosenbrock
fig = plt.figure(figsize=(12, 10))
ax1 = fig.add_subplot(121, projection='3d')
ax1.set_title('Superficie de Rosenbrock')

# Crear una malla de puntos para la superficie de la función de Rosenbrock
x_vals = np.linspace(-3, 3, 100)
y_vals = np.linspace(-3, 3, 100)
x_mesh, y_mesh = np.meshgrid(x_vals, y_vals)
z_mesh = rosenbrock(x_mesh, y_mesh)

# Graficar la superficie de la función de Rosenbrock
ax1.plot_surface(x_mesh, y_mesh, z_mesh, cmap='viridis', alpha=0.8)

# Configuración de la etiqueta de los ejes para la superficie de Rosenbrock
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Costo')

# Realizar una figura 2D para el descenso de gradiente
ax2 = fig.add_subplot(122)
ax2.set_title('Descenso de Gradiente')

# Graficar el historial de puntos encontrados por el descenso de gradiente
ax2.contour(x_mesh, y_mesh, z_mesh, levels=np.logspace(-1, 3, 10), cmap='viridis')
ax2.scatter(historial_x, historial_y, c='r', marker='o')

# Configuración de la etiqueta de los ejes para el descenso de gradiente
ax2.set_xlabel('X')
ax2.set_ylabel('Y')

# Mostrar la gráfica
plt.tight_layout()
plt.show()
